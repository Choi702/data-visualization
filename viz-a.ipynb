# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
mma = pd.read_csv('predictions.csv')

# %%
mma.head()
# Out:
#            winner      loser        date  winner_odds             predictor  \
# 0  Conor McGregor  Jose Aldo  2015-12-12       -104.0       Andrei Arlovski
# 1  Conor McGregor  Jose Aldo  2015-12-12       -104.0  Alexander Gustafsson
# 2  Conor McGregor  Jose Aldo  2015-12-12       -104.0         Travis Browne
# 3  Conor McGregor  Jose Aldo  2015-12-12       -104.0            Clay Guida
# 4  Conor McGregor  Jose Aldo  2015-12-12       -104.0          Ben Rothwell
#
#    correct
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True

# %%
x = mma['predictor']
x
# Out:
# 0            Andrei Arlovski
# 1       Alexander Gustafsson
# 2              Travis Browne
# 3                 Clay Guida
# 4               Ben Rothwell
#                 ...
# 2832            Zak Cummings
# 2833          Jan Blachowicz
# 2834          Gegard Mousasi
# 2835            James Krause
# 2836            Ian Heinisch
# Name: predictor, Length: 2837, dtype: object

# %%
y = mma['correct']
y
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 2832    False
# 2833    False
# 2834    False
# 2835    False
# 2836     True
# Name: correct, Length: 2837, dtype: bool

# %%
a = sns.barplot(x='predictor', y='correct', data = mma)
plt.xticks(rotation=45)

a.set(xlabel='Fighters', ylabel='win predict')
a.set_title('Odds', fontsize=25)
print()
